# %% [markdown]
# # Neo4J Wrapper Connection

# %% [markdown]
# # Py2Neo

# %%
from py2neo import Graph
graph_3 = Graph("https://54.85.112.231:7473/db/data/")

from py2neo import Graph
graph_3 = Graph("https://54.85.112.231:7473/db/data/")

# %% [markdown]
# # Official Neo4j Python Driver

# %%
from neo4j.v1 import GraphDatabase, basic_auth
driver = GraphDatabase.driver("bolt://54.85.112.231:7687", auth=basic_auth("neo4j", "LEbKqX3q"))
session = driver.session()

result = session.run("Match (n:Country)-[a]-(b) Return distinct n")
for record in result:
    print record


session.close()
# Out:
# <Record n=<Node id=1 labels=set([u'Country']) properties={u'Name': u'Afghanistan'}>>
# <Record n=<Node id=486 labels=set([u'Country']) properties={u'Name': u'Aland Islands'}>>
# <Record n=<Node id=497 labels=set([u'Country']) properties={u'Name': u'Albania'}>>
# <Record n=<Node id=738 labels=set([u'Country']) properties={u'Name': u'Algeria'}>>
# <Record n=<Node id=1086 labels=set([u'Country']) properties={u'Name': u'American Samoa'}>>
# <Record n=<Node id=1096 labels=set([u'Country']) properties={u'Name': u'Andorra'}>>
# <Record n=<Node id=1140 labels=set([u'Country']) properties={u'Name': u'Angola'}>>
# <Record n=<Node id=1438 labels=set([u'Country']) properties={u'Name': u'Anguilla'}>>
# <Record n=<Node id=1466 labels=set([u'Country']) properties={u'Name': u'Antarctica'}>>
# <Record n=<Node id=1471 labels=set([u'Country']) properties={u'Name': u'Antigua and Barbuda'}>>
# <Record n=<Node id=1483 labels=set([u'Country']) properties={u'Name': u'Argentina'}>>
# ...

# %% [markdown]
# # Bulbs Neo4J ORM

# %%
NEO4J_URI = 'bolt://54.85.112.231:7687' # Neo4j Server REST API.
NEO4J_URI1 = 'http://54.85.112.231:7777/db/data/' #second one if URL changes
NEO4J_URI2 = 'http://54.85.112.231:7473/db/data/'
NEO4J_URI3 = 'http://54.85.112.231:7474/db/data/' #recommended for this package

# %%
from bulbs.neo4jserver import Graph, Config, NEO4J_URI
config = Config(NEO4J_URI3)
# g = Graph(config)
print NEO4J_URI
# Out:
# http://localhost:7474/db/data/

# %%
config = Config('http://example.dev:7777/db/data/')
g = Graph(config)
'http://localhost:7474/db/data/'
